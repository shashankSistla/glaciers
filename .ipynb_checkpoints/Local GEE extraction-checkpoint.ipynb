# %%
import rasterio

# %%
import ee
import pandas as pd
import rpy2.robjects as robjects
from datetime import datetime, timedelta
import rasterio


ee.Authenticate()

ee.Initialize(project="ee-f20170834h")
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=WfXcNZA484BH3o48s6oXVeofPuCQUrxNXghfu1JFFWs&tc=CGtmeEPwWyrJJ6nQ_LQJQkk-My0GvxD5tvkgPGjs0L0&cc=80xl_mYqXAZihlZ6r7n7BN7dHWS9dh6MZrOMC6dGv94>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=WfXcNZA484BH3o48s6oXVeofPuCQUrxNXghfu1JFFWs&tc=CGtmeEPwWyrJJ6nQ_LQJQkk-My0GvxD5tvkgPGjs0L0&cc=80xl_mYqXAZihlZ6r7n7BN7dHWS9dh6MZrOMC6dGv94</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AeaYSHBP8uG9VMn2sg4yll0K_a4-QjV-dmqC25WFrswCE286Y5By6k0Fls4
#
# Successfully saved authorization token.

# %%
def read_rds(file_path):
    readRDS = robjects.r['readRDS']
    return readRDS(file_path)

def fractional_year_to_date(fractional_year):
    year = int(fractional_year)
    remainder = fractional_year - year
    start_of_year = datetime(year, 1, 1)
    days_in_year = 366 if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0) else 365
    days_to_add = int(remainder * days_in_year)
    target_date = start_of_year + timedelta(days=days_to_add)
    return target_date.strftime('%Y-%m-%d')

# %%
import numpy as np
from tqdm import tqdm

# %%
def get_monthly_stats(image_collection, year, month, geometry):
    start_date = f"{year}-{month:02d}-01"
    end_date = f"{year}-{month:02d}-{pd.Timestamp(start_date).days_in_month}"

    monthly_collection = image_collection.filter(ee.Filter.date(start_date, end_date)).filterBounds(geometry)

    mean_temp = monthly_collection.select(['temperature_2m', 'skin_temperature']).mean()

    total_precip = monthly_collection.select(['total_precipitation']).sum()

    combined_image = mean_temp.addBands(total_precip)

    stats = combined_image.reduceRegion(
        reducer=ee.Reducer.mean().combine(ee.Reducer.sum(), sharedInputs=True),
        geometry=geometry,
        scale=11000,
        maxPixels=10
    )
    return stats.getInfo()

#glaciers = ['G010748E46850N', 'G042869E43218N','G072799E39141N']
glaciers = ['G007276E45599', 'G010748E46850N']
glaciers = ['G077749E41787N', 'G078184E41824N']
glaciers = ['G010748E46850N','G077277E43048N','G077314E43095N','G077333E32259N','G077342E32257N','G077358E32209N','G077513E32227N']
glaciers = ['G077314E43095N','G077333E32259N','G077342E32257N','G077358E32209N','G077513E32227N']
glaciers = ['G007880E45990N','G007603E46067N', 'G007663E45970N', 'G007702E46120N', 'G007761E45922N', 'G007794E45916N', 'G007807E46481N', 'G007846E45906N', 'G007858E45898N', 'G007867E46119N', 'G007882E45908N', 'G007887E45948N', 'G007908E45948N', 'G007930E46472N', 'G008006E46177N', 'G008010E46463N',  'G008087E46260N']

# done glaciers = ['G007581E46002N']


for glacier in glaciers:
    print(f"Currently processing glacier {glacier}")
    file_path = f'./output/restart/03_extract_IP/{glacier}_dates_cut.rds'
    file_path = f'C:\\Users\\shash\\OneDrive\\Desktop\\Research\\Glacier Revamp\\output\\restart\\03_extract_IP\\output\\{glacier}_dates_cut.rds'
  #reading the rds file to get timestamps from it
    dates = read_rds(file_path)
    tt = np.array(dates)
    dates = [fractional_year_to_date(year) for year in tt]

  #tif file path
    path = f'C:\\Users\\shash\\OneDrive\\Desktop\\Research\\Glacier Revamp\\data\\DigitalElevationModels\\{glacier}_NASADEM.tif'
    

    with rasterio.open(path) as dataset:
        bounds = dataset.bounds
        ulx, lry, lrx, uly = bounds.left, bounds.bottom, bounds.right, bounds.top
        crs = dataset.crs.to_string()
        bbox = [[ulx, uly], [lrx, uly], [lrx, lry], [ulx, lry], [ulx, uly]]
        res = dataset.res

        geometry = ee.Geometry.Polygon([bbox])
        print(crs)
        print(res)


          # Find the earliest and latest years
        earliest_year = min(pd.to_datetime(dates).year)
        latest_year = max(pd.to_datetime(dates).year)

        # Create a list of all months within this range
        tasks = [(year, month) for year in range(earliest_year, latest_year + 1) for month in range(1, 13)]

        # Image collection
        image_collection = ee.ImageCollection('ECMWF/ERA5_LAND/HOURLY').select(['temperature_2m', 'skin_temperature', 'total_precipitation'])

          # List to store the data before creating DataFrame
        results = []



        for task in tqdm(tasks):
            year, month = task
            #print(f"Processing {year}-{month:02d}")
            stats = get_monthly_stats(image_collection, year, month, geometry)
            results.append({
                'Year': year,
                'Month': month,
                'Temperature_2m': stats.get('temperature_2m_mean'),
                'Skin_Temperature': stats.get('skin_temperature_mean'),
                'Total_Precipitation': stats.get('total_precipitation_sum')
                })
        results_df = pd.DataFrame(results)
        filename = f"{glacier}_env.csv"

  # Sort the DataFrame by Year and Month, and save
        sorted_results_df = results_df.sort_values(by=['Year', 'Month']).reset_index(drop=True)
        sorted_results_df.to_csv(filename, index=False)
        print(f"Data saved to {filename}")
# Out:
# Currently processing glacier G007581E46002N
# EPSG:4326
# (0.0002694945852358564, 0.0002694945852358564)
# 100%|██████████████████████████████████████████████████████████████████████████████| 456/456 [1:41:26<00:00, 13.35s/it]
# Data saved to G007581E46002N_env.csv
# Currently processing glacier G007603E46067N
# EPSG:4326
# (0.0002694945852358564, 0.0002694945852358564)
#   1%|█                                                                                 | 6/456 [00:44<55:42,  7.43s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 31>()
#      72     year, month = task
#      73     #print(f"Processing {year}-{month:02d}")
# ---> 74     stats = get_monthly_stats(image_collection, year, month, geometry)
#      75     results.append({
#      76         'Year': year,
#      77         'Month': month,
#    (...)
#      80         'Total_Precipitation': stats.get('total_precipitation_sum')
#      81         })
#      82 results_df = pd.DataFrame(results)
#
# Input In [19], in get_monthly_stats(image_collection, year, month, geometry)
#      11 combined_image = mean_temp.addBands(total_precip)
#      13 stats = combined_image.reduceRegion(
#      14     reducer=ee.Reducer.mean().combine(ee.Reducer.sum(), sharedInputs=True),
#      15     geometry=geometry,
#      16     scale=30,
#      17     maxPixels=1e13
#      18 )
# ---> 19 return stats.getInfo()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\computedobject.py:105, in ComputedObject.getInfo(self)
#      99 def getInfo(self) -> Optional[Any]:
#     100   """Fetch and return information about this object.
#     101
#     102   Returns:
#     103     The object can evaluate to anything.
#     104   """
# --> 105   return data.computeValue(self)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:1070, in computeValue(obj)
#    1067 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1068 _maybe_populate_workload_tag(body)
# -> 1070 return _execute_cloud_call(
#    1071     _get_cloud_projects()
#    1072     .value()
#    1073     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1074 )['result']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:371, in _execute_cloud_call(call, num_retries)
#     357 """Executes a Cloud API call and translates errors to EEExceptions.
#     358
#     359 Args:
#    (...)
#     368   EEException if the call fails.
#     369 """
#     370 try:
# --> 371   return call.execute(num_retries=num_retries)
#     372 except googleapiclient.errors.HttpError as e:
#     373   raise _translate_cloud_exception(e)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\_cloud_api_utils.py:66, in _Http.request(***failed resolving arguments***)
#      63 del connection_type  # Ignored
#      64 del redirections  # Ignored
# ---> 66 response = self._session.request(
#      67     method, uri, data=body, headers=headers, timeout=self._timeout
#      68 )
#      69 headers = dict(response.headers)
#      70 headers['status'] = response.status_code
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def process_monthly_data(image):
    date = image.date().format('YYYY-MM')
    stats = image.reduceRegion(
        reducer=ee.Reducer.mean().combine(ee.Reducer.sum(), sharedInputs=True),
        geometry=geometry,
        scale=11000,
        maxPixels=10
    )
    # Correctly constructing the feature with all statistics and date
    feature = ee.Feature(None, {'date': date}).setMulti(stats)
    return feature


def get_multi_year_stats(image_collection, start_year, end_year, geometry):
    start_date = f"{start_year}-01-01"
    
    end_date = f"{end_year}-12-31"
    multi_year_collection = image_collection.filter(ee.Filter.date(start_date, end_date)).filterBounds(geometry)
    monthly_features = multi_year_collection.map(process_monthly_data)
    return monthly_features.getInfo()  # Returns the processed data as a list of features




#glaciers = ['G010748E46850N', 'G042869E43218N','G072799E39141N']
glaciers = ['G007276E45599', 'G010748E46850N']
glaciers = ['G077749E41787N', 'G078184E41824N']
glaciers = ['G010748E46850N','G077277E43048N','G077314E43095N','G077333E32259N','G077342E32257N','G077358E32209N','G077513E32227N']
glaciers = ['G077314E43095N','G077333E32259N','G077342E32257N','G077358E32209N','G077513E32227N']
glaciers = ['G007603E46067N', 'G007663E45970N', 'G007702E46120N', 'G007761E45922N', 'G007794E45916N', 'G007807E46481N', 'G007846E45906N', 'G007858E45898N', 'G007867E46119N', 'G007880E45990N', 'G007882E45908N', 'G007887E45948N', 'G007908E45948N', 'G007930E46472N', 'G008006E46177N', 'G008010E46463N',  'G008087E46260N']

# done glaciers = ['G007581E46002N']


for glacier in glaciers:
    print(f"Currently processing glacier {glacier}")
    file_path = f'./output/restart/03_extract_IP/{glacier}_dates_cut.rds'
    file_path = f'C:\\Users\\shash\\OneDrive\\Desktop\\Research\\Glacier Revamp\\output\\restart\\03_extract_IP\\output\\{glacier}_dates_cut.rds'
  #reading the rds file to get timestamps from it
    dates = read_rds(file_path)
    tt = np.array(dates)
    dates = [fractional_year_to_date(year) for year in tt]

  #tif file path
    path = f'C:\\Users\\shash\\OneDrive\\Desktop\\Research\\Glacier Revamp\\data\\DigitalElevationModels\\{glacier}_NASADEM.tif'
    

    with rasterio.open(path) as dataset:
        bounds = dataset.bounds
        ulx, lry, lrx, uly = bounds.left, bounds.bottom, bounds.right, bounds.top
        crs = dataset.crs.to_string()
        bbox = [[ulx, uly], [lrx, uly], [lrx, lry], [ulx, lry], [ulx, uly]]
        res = dataset.res

        geometry = ee.Geometry.Polygon([bbox])
        print(crs)
        print(res)


        for year_block in range(earliest_year, latest_year + 1, 5):
                end_year = min(year_block + 4, latest_year)  # Ensure we do not exceed the latest year
                print(f"Processing from {year_block} to {end_year}")

                # Fetching stats for the current 5-year block
                stats = get_multi_year_stats(image_collection, year_block, end_year, geometry)

                # Assuming a function to convert stats to a DataFrame and save it
                # Convert the list of dictionaries into a DataFrame
                data = [{
                    'Date': feature['properties']['date'],
                    'Temperature_2m': feature['properties'].get('temperature_2m_mean', None),
                    'Skin_Temperature': feature['properties'].get('skin_temperature_mean', None),
                    'Total_Precipitation': feature['properties'].get('total_precipitation_sum', None)
                } for feature in stats['features']]

                results_df = pd.DataFrame(data)
        
        # Define the filename to include the range of years processed
        filename = f"./output/{glacier}_environmental_data_{year_block}_to_{end_year}.csv"
        results_df.to_csv(filename, index=False)
        print(f"Data saved to {filename}")
# Out:
# Currently processing glacier G007603E46067N
# EPSG:4326
# (0.0002694945852358564, 0.0002694945852358564)
# Processing from 1984 to 1988
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:371, in _execute_cloud_call(call, num_retries)
#     370 try:
# --> 371   return call.execute(num_retries=num_retries)
#     372 except googleapiclient.errors.HttpError as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/ee-f20170834h/value:compute?prettyPrint=false&alt=json returned "Collection query aborted after accumulating over 5000 elements.". Details: "Collection query aborted after accumulating over 5000 elements.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Input In [27], in <cell line: 35>()
#      62 print(f"Processing from {year_block} to {end_year}")
#      64 # Fetching stats for the current 5-year block
# ---> 65 stats = get_multi_year_stats(image_collection, year_block, end_year, geometry)
#      67 # Assuming a function to convert stats to a DataFrame and save it
#      68 # Convert the list of dictionaries into a DataFrame
#      69 data = [{
#      70     'Date': feature['properties']['date'],
#      71     'Temperature_2m': feature['properties'].get('temperature_2m_mean', None),
#      72     'Skin_Temperature': feature['properties'].get('skin_temperature_mean', None),
#      73     'Total_Precipitation': feature['properties'].get('total_precipitation_sum', None)
#      74 } for feature in stats['features']]
#
# Input In [27], in get_multi_year_stats(image_collection, start_year, end_year, geometry)
#      18 multi_year_collection = image_collection.filter(ee.Filter.date(start_date, end_date)).filterBounds(geometry)
#      19 monthly_features = multi_year_collection.map(process_monthly_data)
# ---> 20 return monthly_features.getInfo()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\collection.py:157, in Collection.getInfo(self)
#     144 def getInfo(self) -> Optional[Any]:
#     145   """Returns all the known information about this collection.
#     146
#     147   This function makes a REST call to to retrieve all the known information
#    (...)
#     155          properties.
#     156   """
# --> 157   return super().getInfo()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\computedobject.py:105, in ComputedObject.getInfo(self)
#      99 def getInfo(self) -> Optional[Any]:
#     100   """Fetch and return information about this object.
#     101
#     102   Returns:
#     103     The object can evaluate to anything.
#     104   """
# --> 105   return data.computeValue(self)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:1070, in computeValue(obj)
#    1067 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1068 _maybe_populate_workload_tag(body)
# -> 1070 return _execute_cloud_call(
#    1071     _get_cloud_projects()
#    1072     .value()
#    1073     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1074 )['result']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:373, in _execute_cloud_call(call, num_retries)
#     371   return call.execute(num_retries=num_retries)
#     372 except googleapiclient.errors.HttpError as e:
# --> 373   raise _translate_cloud_exception(e)
#
# EEException: Collection query aborted after accumulating over 5000 elements.

# %%
def process_monthly_data(image):
    date = image.date().format('YYYY-MM')
    stats = image.reduceRegion(
        reducer=ee.Reducer.mean().combine(ee.Reducer.sum(), sharedInputs=True),
        geometry=geometry,
        scale=11000,
        maxPixels=10
    )
    # Correctly constructing the feature with all statistics and date
    feature = ee.Feature(None, {'date': date}).setMulti(stats)
    return feature

def get_multi_year_stats(image_collection, year, geometry):
    start_date = f"{year}-01-01"
    end_date = f"{year}-12-31"
    yearly_collection = image_collection.filter(ee.Filter.date(start_date, end_date)).filterBounds(geometry)
    monthly_features = yearly_collection.map(process_monthly_data)
    return monthly_features.getInfo()  # Returns the processed data as a list of features

# Loop to process each glacier, one year at a time
for glacier in glaciers:
    print(f"Currently processing glacier {glacier}")
    file_path = f'C:\\Users\\shash\\OneDrive\\Desktop\\Research\\Glacier Revamp\\output\\restart\\03_extract_IP\\output\\{glacier}_dates_cut.rds'
    dates = read_rds(file_path)
    tt = np.array(dates)
    dates = [fractional_year_to_date(year) for year in tt]

    path = f'C:\\Users\\shash\\OneDrive\\Desktop\\Research\\Glacier Revamp\\data\\DigitalElevationModels\\{glacier}_NASADEM.tif'
    with rasterio.open(path) as dataset:
        bounds = dataset.bounds
        ulx, lry, lrx, uly = bounds.left, bounds.bottom, bounds.right, bounds.top
        bbox = [[ulx, uly], [lrx, uly], [lrx, lry], [ulx, lry], [ulx, uly]]
        geometry = ee.Geometry.Polygon([bbox])
        print(f"CRS: {dataset.crs.to_string()}, Resolution: {dataset.res}")

        # Find the earliest and latest years
        earliest_year = min(pd.to_datetime(dates).year)
        latest_year = max(pd.to_datetime(dates).year)

        for year in range(earliest_year, latest_year + 1):
            print(f"Processing year {year}")
            stats = get_multi_year_stats(image_collection, year, geometry)

            # Convert the list of dictionaries into a DataFrame
            data = [{
                'Date': feature['properties']['date'],
                'Temperature_2m': feature['properties'].get('temperature_2m_mean', None),
                'Skin_Temperature': feature['properties'].get('skin_temperature_mean', None),
                'Total_Precipitation': feature['properties'].get('total_precipitation_sum', None)
            } for feature in stats['features']]

            results_df = pd.DataFrame(data)
            filename = f"./output/{glacier}_environmental_data_{year}.csv"
            results_df.to_csv(filename, index=False)
            print(f"Data saved to {filename}")
# Out:
# Currently processing glacier G007603E46067N
# CRS: EPSG:4326, Resolution: (0.0002694945852358564, 0.0002694945852358564)
# Processing year 1984
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:371, in _execute_cloud_call(call, num_retries)
#     370 try:
# --> 371   return call.execute(num_retries=num_retries)
#     372 except googleapiclient.errors.HttpError as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/ee-f20170834h/value:compute?prettyPrint=false&alt=json returned "Collection query aborted after accumulating over 5000 elements.". Details: "Collection query aborted after accumulating over 5000 elements.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Input In [28], in <cell line: 21>()
#      40 for year in range(earliest_year, latest_year + 1):
#      41     print(f"Processing year {year}")
# ---> 42     stats = get_multi_year_stats(image_collection, year, geometry)
#      44     # Convert the list of dictionaries into a DataFrame
#      45     data = [{
#      46         'Date': feature['properties']['date'],
#      47         'Temperature_2m': feature['properties'].get('temperature_2m_mean', None),
#      48         'Skin_Temperature': feature['properties'].get('skin_temperature_mean', None),
#      49         'Total_Precipitation': feature['properties'].get('total_precipitation_sum', None)
#      50     } for feature in stats['features']]
#
# Input In [28], in get_multi_year_stats(image_collection, year, geometry)
#      16 yearly_collection = image_collection.filter(ee.Filter.date(start_date, end_date)).filterBounds(geometry)
#      17 monthly_features = yearly_collection.map(process_monthly_data)
# ---> 18 return monthly_features.getInfo()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\collection.py:157, in Collection.getInfo(self)
#     144 def getInfo(self) -> Optional[Any]:
#     145   """Returns all the known information about this collection.
#     146
#     147   This function makes a REST call to to retrieve all the known information
#    (...)
#     155          properties.
#     156   """
# --> 157   return super().getInfo()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\computedobject.py:105, in ComputedObject.getInfo(self)
#      99 def getInfo(self) -> Optional[Any]:
#     100   """Fetch and return information about this object.
#     101
#     102   Returns:
#     103     The object can evaluate to anything.
#     104   """
# --> 105   return data.computeValue(self)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:1070, in computeValue(obj)
#    1067 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1068 _maybe_populate_workload_tag(body)
# -> 1070 return _execute_cloud_call(
#    1071     _get_cloud_projects()
#    1072     .value()
#    1073     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1074 )['result']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:373, in _execute_cloud_call(call, num_retries)
#     371   return call.execute(num_retries=num_retries)
#     372 except googleapiclient.errors.HttpError as e:
# --> 373   raise _translate_cloud_exception(e)
#
# EEException: Collection query aborted after accumulating over 5000 elements.
